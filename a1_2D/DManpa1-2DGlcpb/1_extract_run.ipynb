# %%
import sys
import subprocess
import os 

import glob
import multiprocessing

# %%
sys.path.append('../../')
from extract_glycan_info import parse_gf_result
# Out:
# ===============================================================================
# Script: Find glycosidic dihedral, average B-factor, and ring shape of glycans from PDB
# Author:Rajan Kandel <rajan.kandel@uga.edu>
#       *Woods Group, CCRC UGA
#
# Currently under development.......
# Last Update: Oct 2024
#
# Citations:
# 1. https://glycam.org/cb/
# 2. https://glycam.org/portal/gf_home/
#
# ===============================================================================

# %%
phi_dihedral=['C2','C1','O2','C2']
psi_dihedral=['C1','O2','C2','C3']

di_sugar=['MAN', 'BGC']
patterns1= ['MAN(*_*_)]-BGC(*_*_)', 'MAN(*_*_)-BGC(*_*_)','MAN(*_*_)]-[*]-BGC(*_*_)', 'MAN(*_*_)-[*]-BGC(*_*_)']
patterns2= ['DManpa1-2DGlcpb', 'DManpa1-2]DGlcpb', 'DManpa1-2[*]DGlcpb']
patterns=(patterns1,patterns2)

gf_result ='../../data_gf_query/a1-2D_GF_results.csv'

chimerax_path= '/bin/chimerax'
bfmp_path = '/home/rajan/apps/BFMP/detect_shape'


instant1 = parse_gf_result(gf_result, phi_dihedral, psi_dihedral, di_sugar, patterns, chimerax_path, bfmp_path)
instant1.read_gf_file()
instant1.dnl_pdbs()
instant1.create_pdb_glycan_dict() 
instant1.glycan_count()
instant1.select_pdbs()
# Out:
# ========== Reading_gf_results =====================================
# pdbs: ['1A0T', '1A0T', '1A0T', '1A0T', '1A0T', '1A0T', '1A14', '1AA5', '1AA5', '1AF6', '1AF6', '1AF6', '1AFC', '1AFC', '1AFC', '1AFC', '1AFC', '1AFC', '1AFC', '1AFC', '1AGM', '1AGM', '1BHG', '1BHG', '1BJI', '1BRR', '1BRR', '1BXH', '1BXH', '1BZB', '1C0Q', '1C0Q', '1C0R', '1C0R', '1C3N', '1CAP', '1CB8', '1CF3', '1CKL', '1CKL', '1CKL', '1CLY', '1CLZ', '1CPO', '1DBG', '1DBO', '1DOG', '1DOG', '1DP5', '1DPJ', '1DSR', '1DZE', '1E05', '1EX2', '1F4Y', '1F6A', '1F8B', '1F8C', '1F8D', '1F8E', '1FE0', '1FE4', '1FEE', '1FI1', '1FQ6', '1FVM', '1FVM', '1FVM', '1FVM', '1FVM', '1FVM', '1G0V', '1GAC', '1GAC', '1GAH', '1GAH', '1GAI', '1GAI', '1GAL', '1GLM', '1GLM', '1GNX', '1GPE', '1GPE', '1GSL', '1GW0', '1GW0', '1GYA', '1GZ9', '1H3X', '1H3Y', '1H4P', '1H4P', '1HFU', '1HH3', '1HH3', '1HH3', '1HH3', '1HHA', '1HHA', '1HHA', '1HHA', '1HHC', '1HHC', '1HHC', '1HHC', '1HHF', '1HHF', '1HHF', '1HHF', '1HM2', '1HM2', '1HM3', '1HM3', '1HMU', '1HMU', '1HMW', '1HMW', '1I1A', '1I3H', '1IIY', '1IIY', '1ING', '1ING', '1INY', '1IVD', '1IVD', '1IVF', '1IVF', '1
X', '5VX9', '5UFF', '2HVI', '4X4K', '6FYW', '7WAB', '1NKE', '3GMO', '5JS9', '5M0S', '6VKN', '2UUS', '4QB6', '5NFF', '5XN0', '7L09', '6HUG', '5NN9', '3NKR', '1U2T', '2Q9O', '2XJS', '1JCQ', '5O8L', '6MGK', '7S7F', '8GPJ', '3AST', '4END', '6TP5', '5FMC', '5ANN', '6OML', '7A0Q', '4M00', '1QZ6', '3HPO', '6OPO', '4OP7', '6EZN', '8EJH', '8DDK', '8DCF', '4YFU', '1R82', '6QP7', '3NKN', '7U4F', '1DOG', '3GMP', '5S9L', '4MWY', '1R81', '1OW0', '4KH2', '3HN3', '7TEM', '1TYX', '6SKA', '7LRX', '8D3Z', '6Q20', '7K37', '1XOE', '7LRF', '8G30', '7FDZ', '3QVP', '4ZXW', '3CXH', '3ES6', '3PA2', '4KV8', '5KIJ', '7LXM', '6V0R', '6BI4', '1ING', '4ISJ', '3WAY', '2BE2', '6HAK', '6CH8', '6MTJ', '6WM2', '2QQU', '5LIA', '3UGG', '5V8M', '3WJM', '1JGI', '7UOJ', '4P25', '3PMA', '3TYG', '6X3X', '6HG0', '6W35', '7X9O', '6NNF', '2J6E', '5AE6', '5CEZ', '5ELE', '3NKP', '2CIY', '2Y24', '5KOE', '1V0Z', '3ASQ', '4DS0', '4B9S', '6ORH', '1JJ0', '3J4P', '3SLN', '3SP3', '4DGR', '5DK3', '6MZJ', '5VN3', '8DD2', '4F2R', '1XC6', '7ZCR', '3I0G', '5NBS', '7LRM', '5KK7', '1YLP', '3Q7A', '4K1K', '4WZE', '6HA0', '7WW7', '8SAW', '1V8X', '1HMW', '2WAH', '5ES4', '6DE7', '3U75', '2OBT', '6WIX', '4I9E', '4BXS', '3PUN', '1PNV', '4HIZ', '6U7H', '1MW2', '6JBS', '7W3V', '1IVD', '7L8Z', '3SAJ', '3BYN', '6EAY', '1IW6',  ...
# ===================================================================
# {'1A0T': {'glycan_name': ['DGlcpa2-1DFrufb', 'DGlcpa2-1DFrufb', 'DGlcpa2-1DFrufb', 'DGlcpa2-1DFrufb', 'DGlcpa2-1DFrufb', 'DGlcpa2-1DFrufb'], 'glycan_residueID': ['GLC(1_A_)-FRU(2_A_)', 'GLC(1_E_)-FRU(2_E_)', 'GLC(1_C_)-FRU(2_C_)', 'GLC(1_D_)-FRU(2_D_)', 'GLC(1_B_)-FRU(2_B_)', 'GLC(1_F_)-FRU(2_F_)']}, '1A14': {'glycan_name': ['DManpa1-2DManpa1-2DManpa1-3DManpb1-4DGlcpNAcb1-4DGlcpNAcb1-ASN'], 'glycan_residueID': ['MAN(6_A_)-MAN(5_A_)-MAN(4_A_)-BMA(3_A_)-NAG(2_A_)-NAG(1_A_)-ASN(200_N_)']}, '1AA5': {'glycan_name': ['LGalp[6H,2H,3<R1>]a1-2DGlcpb1-C49N6O15', 'LGalp[6H,2H,3<R1>]a1-2DGlcpb1-C49N6O15'], 'glycan_residueID': ['RER(2_C_)-BGC(1_C_)-GHP(4_A_)', 'RER(2_D_)-BGC(1_D_)-GHP(4_B_)']}, '1AF6': {'glycan_name': ['DGlcpa2-1DFrufb', 'DGlcpa2-1DFrufb', 'DGlcpa2-1DFrufb'], 'glycan_residueID': ['GLC(1_F_)-FRU(2_F_)', 'GLC(1_D_)-FRU(2_D_)', 'GLC(1_E_)-FRU(2_E_)']}, '1AFC': {'glycan_name': ['DGlcp[2S,3S,4S,6S]a2-1DFruf[3S,-1S,5S]b', 'DGlcp[2S,3S,6S]a2-1DFruf[2<R1>,3S,-1S]b', 'DGlcp[2S,3S,6S]a2-1DFruf[2<R1>,3S,-1S,5S]b', 'DGlcp[2S,3S,6S]a2-1DFruf[2S,3S,-1S,5S]b', 'DGlcp[3S,6S]a2-1DFruf[3S,-1S,5S]b', 'DGlcp[2S,3S,4S]a2-1DFruf[2<R1>,3S,-1S,5S]b', 'DGlcp[2S,3S,6S]a2-1DFruf[3S,-1S,5S]b', 'DGlcp[2S,3S,6S]a2-1DFruf[3S,4S,1<R1>,6S]b'], 'glycan_residueID': ['GU4(1_J_)-[YYJ(2_J_)', 'GU4(1_M_)-[YYJ(2_M_)', 'GU4(1_N_)-[YYJ(2_N_)', 'GU4(1_L_)-[YYJ(2_L_)', 'GU4(1_P_)-[YYJ(2_P_)', 'GU4(1_O_)-[YYJ(2_O_)', 'GU4(1_I_)-[YYJ(2_I_)', 'GU4(1_K_)-YYJ(2_K_)']}, '1AGM': {'glycan_name': ['DManpa1-2DManpa1-3DManpb1-4DGlcpNAcb1-4DGlcpNAcb1-ASN', 'DManpa1-2DManpa1-2DManpa1-3[DManpa1-3DManpa1-6]DManpb1-4DGlcpNAcb1-4DGlcpNAcb1-ASN'], 'glycan_residueID': ['MAN(5_B_)-MAN(4_B_)-BMA(3_B_)-NAG(2_B_)-NAG(1_B_)-ASN(171_A_)', 'MAN(8_C_)-MAN(7_C_)-[MAN(6_C_)-MAN(5_C_)-MAN(4_C_)]-BMA(3_C_)-NAG(2_C_)-NAG(1_C_)-ASN(395_A_)']}, '1BHG': {'glycan_name': ['DManpa1-2DManpa1-6[DManpa1-3]DManpa1-6[DManpa1-2DManpa1-3]DManpb1-4DGlcpNAcb1-4DGlcpNAcb1-ASN', 'DManpa1-2DManpa1-6[DManpa1-3]DManpa1-6[DManpa1-2DManpa1-3]DManpb1-4DGlcpNAcb1-4DGlcpNAcb1-ASN'], 'glycan_residueID': ['MAN(6_C_)-MAN(5_C_)-[MAN(7_C_)]-MAN(4_C_)-[MAN(9_C_)-MAN(8_C_)]-BMA(3_C_)-NAG(2_C_)-NAG(1_C_)-ASN(173_A_)', 'MAN(6_D_)-MAN(5_D_)-[MAN(7_D_)]-MAN(4_D_)-[MAN(9_D_)-MAN(8_D_)]-BMA(3_D_)-NAG(2_D_)-NAG(1_D_)-ASN(173_B_)']}, '1BJI': {'glycan_name': ['DManpa1-2DManpa1-2DManpa1-3DManpb1-4DGlcpNAcb1-4DGlcpNAcb1-ASN'], 'glycan_residueID': ['MAN(6_B_)-MAN(5_B_)-MAN(4_B_)-BMA(3_B_)-NAG(2_B_)-NAG(1_B_)-ASN(200_A_)']}, '1BRR': {'glycan_name': ['DGalp[3S]b1-6DManpa1-2DGlcpa1-C43O3', 'DGalp[3S]b1-6DManpa1-2DGlcpa1-C43O3'], 'glycan_residueID': ['SGA(3_E_)-MAN(2_E_)-GLC(1_E_)', 'SGA(3_D_)-MAN(2_D_)-GLC(1_D_)']}, '1BXH': {'glycan_name': ['DManpa1-2DManpa1-OME', 'DManpa1-2DManpa1-OME'], 'glycan_residueID': ['AMG(2_E_)-MMA(1_E_)', 'AMG(2_F_)-AMG(1_F_)']}, '1BZB': {'glycan_name': ['DManpa1-2DManpa1-3[DManpa1-3[DManpa1-6]DManpa1-6]DManpb1-4DGlcpNAcb1-4DGlcpNAcb1-ASN'], 'glycan_residueID': ['MAN(8_B_)-[MAN(7_B_)]-MAN(6_B_)-[MAN(5_B_)-MAN(4_B_)]-MAN(3_B_)-NAG(2_B_)-NAG(1_B_)-ASN(3_A_)']}, '1C0Q': {'glycan_name': ['LGalp[6H,2H,3<R1>]a1-2DGlcpb1-C49N6O15', 'LGalp[6H,2H,3<R1>]a1-2DGlcpb1-C49N6O15'], 'glycan_residueID': ['RER(2_C_)-BGC(1_C_)-GHP(4_A_)', 'RER(2_D_)-BGC(1_D_)-GHP(4_B_)']}, '1C0R': {'glycan_name': ['LGalp[6H,2H,3<R1>]a1-2DGlcpb1-C49N6O15', 'LGalp[6H,2H,3<R1>]a1-2DGlcpb1-C49N6O15'], 'glycan_residueID': ['RER(2_C_)-BGC(1_C_)-GHP(4_A_)', 'RER(2_D_)-BGC(1_D_)-GHP(4_B_)']}, '1C3N': {'glycan_name': ['DManpa1-2DManpa1-ROH'], 'glycan_residueID': ['MAN(2_B_)-MAN(1_B_)']}, '1CAP': {'glycan_name': ['DManpa1-3DGlcpb1-3[DManp[2<R1>]a1-4]DGlcpAb1-3DGalpa1-2DManpa1-3DGlcpb1-3[DManp[2<R2>]a1-4]DGlcpAb1-3DGalpx1-'], 'glycan_residueID': ['MAN(11_A_)-MAN(9_A_)-[MAN(8_A_)-BGC(7_A_)]-BDP(6_A_)-GAL(5_A_)-MAN(4_A_)-BGC(3_A_)]-BDP(2_A_)-GAL(1_A_)']}, '1CB8': {'glycan_name': ['LFucp[2Me][2Me]a1-4DXylpb1-4DGlcpAa1-2[LRhapa1-4]DManpa1-SER'], 'glycan_residueID': ['RAM(5_B_)-MFU(4_B_)-XYP(3_B_)-GCU(2_B_)]-MAN(1_B_)-SER(455_A_)']}, '1CF3': {'glycan_name': ['DManpa1- ...
# total_pdb_count: 1483
# glycosite_count: 3193

# %%
# %%capture output
instant1.generate_chimerax_script_to_compute_dihedral()

# %%
# Write the entire output to a file
with open('calc_dihedral2.cxc', 'w') as f:
    f.write(output.stdout)

# %%
# Use the custom split function
instant1.custom_split_chimerax_script('calc_dihedral2.cxc', 'calc_dihedral_part_')
# Out:
# chimerax script is run parallely in ./calc_dihedral_chimerax
# Split into 1 files.

# %%
# Run the parallel execution and stitching
instant1.run_chimerax_script_parallel('./calc_dihedral_chimerax/calc_dihedral_part_*.cxc')
# Out:
# Executed 1 ChimeraX scripts in parallel.
# Combined outputs into:  combined_chimerax_output.out

# %%
# instant1.run_chimerax_script('calc_dihedral2.cxc', 'calc_dihedral2.out')

# %%
# torsions = instant1.clean_up_chimerax_output('calc_dihedral2.out')
torsions = instant1.clean_up_chimerax_output('combined_chimerax_output.out')
torsions.to_csv('chimerax_output.csv', index=False)
# Out:
# number of pdb read: 2
# valid torsion1 and torsion2: (2, 2)

# %%
instant1.calc_BFactor()

# %%
instant1.find_bfmp_ring_shape()
# Out:
# (['2.E', '1.E'], ['4C1', '4C1'])
# (['2.D', '1.D'], ['4C1', '4C1'])

# %%
output_df = instant1.match_glycan_tree()
# Out:
# ../../pdbs//3rum.pdb E MAN 2 C1
# ../../pdbs//3rum.pdb E BGC 1 O2
# 3141 3136
# Connection found between 3141 and 3136
# ../../pdbs//3rum.pdb D MAN 2 C1
# ../../pdbs//3rum.pdb D BGC 1 O2
# 3100 3095
# Connection found between 3100 and 3095
# droped rows: []

# %%
output_df.to_csv('DManpa1-2DGlcpb_ver2.1.csv',sep=',',index=False, columns=['pdb','glycam name','glycan','phi site','psi site','phi','psi','B factor(Avg)','BFMP ring shape'])
output_df.to_csv('DManpa1-2DGlcpb_ver3.csv',sep=',',index=False, columns=['pdb','phi site','psi site','phi','psi','B factor(Avg)','BFMP ring shape'])

# %%
################################
# print(instant1.pdbs)
# print(instant1.pdb_glycan_dict)

# %%
instant1.torsions
# Out:
#         pdb                   phi site                   psi site      phi  \
# 0  3rum.pdb  E MAN 2 C2 C1 BGC 1 O2 C2  E MAN 2 C1 BGC 1 O2 C2 C3  198.431
# 1  3rum.pdb  D MAN 2 C2 C1 BGC 1 O2 C2  D MAN 2 C1 BGC 1 O2 C2 C3  180.780
#
#        psi                             B factor(Avg)  \
# 0  212.554  ([MAN(2_E_), BGC(1_E_)], [42.48, 23.33])
# 1  211.451  ([MAN(2_D_), BGC(1_D_)], [27.23, 23.21])
#
#                                               glycan  \
# 0  RAM(4_E_)-[BXY(3_E_)-MAN(2_E_)]-BGC(1_E_)-GHP(...
# 1  RAM(4_D_)-[BXY(3_D_)-MAN(2_D_)]-BGC(1_D_)-GHP(...
#
#                                      glycam name           BFMP ring shape
# 0  DArafa1-2DManpa1-2[LRhapa1-6]DGlcpb1-C60N7O19  ([2.E, 1.E], [4C1, 4C1])
# 1  DArafa1-2DManpa1-2[LRhapa1-6]DGlcpb1-C60N7O19  ([2.D, 1.D], [4C1, 4C1])

# %%
instant1.plot(torsions=instant1.torsions, title='DManpa1-2DGlcpb',max_histogram_scale=100,step_histogram_tick=20)
