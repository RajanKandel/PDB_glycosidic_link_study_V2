# %%
import sys
import subprocess
import os 

import glob
import multiprocessing

# %%
sys.path.append('../../')
from extract_glycan_info import parse_gf_result
# Out:
# ===============================================================================
# Script: Find glycosidic dihedral, average B-factor, and ring shape of glycans from PDB
# Author:Rajan Kandel <rajan.kandel@uga.edu>
#       *Woods Group, CCRC UGA
#
# Currently under development.......
# Last Update: Oct 2024
#
# Citations:
# 1. https://glycam.org/cb/
# 2. https://glycam.org/portal/gf_home/
#
# ===============================================================================

# %%
phi_dihedral=['C2','C1','O3','C3']
psi_dihedral=['C1','O3','C3','C4']

di_sugar=['MAN', 'BGC']
patterns1= ['MAN(*_*_)]-BGC(*_*_)', 'MAN(*_*_)-BGC(*_*_)','MAN(*_*_)]-[*]-BGC(*_*_)', 'MAN(*_*_)-[*]-BGC(*_*_)']
patterns2= ['DManpa1-3DGlcpb', 'DManpa1-3]DGlcpb', 'DManpa1-3[*]DGlcpb']
patterns=(patterns1,patterns2)

gf_result ='../../data_gf_query/a1-3D_GF_results.csv'

chimerax_path= '/bin/chimerax'
bfmp_path = '/home/rajan/apps/BFMP/detect_shape'


instant1 = parse_gf_result(gf_result, phi_dihedral, psi_dihedral, di_sugar, patterns, chimerax_path, bfmp_path)
instant1.read_gf_file()
instant1.dnl_pdbs()
instant1.create_pdb_glycan_dict() 
instant1.glycan_count()
instant1.select_pdbs()
# Out:
# ========== Reading_gf_results =====================================
# pdbs: ['146D', '146D', '1A14', '1ABR', '1ABR', '1AGM', '1AGM', '1AX0', '1AX1', '1AX2', '1AXY', '1AXZ', '1AY2', '1B37', '1B5F', '1B5F', '1B5F', '1B5F', '1B5Q', '1BCS', '1BHG', '1BHG', '1BJI', '1BLF', '1BP8', '1BP8', '1BP8', '1BP8', '1BZB', '1C1Z', '1C39', '1C39', '1C3M', '1CAP', '1CF3', '1CKL', '1CKL', '1CKL', '1CKL', '1CKL', '1CKL', '1CLY', '1CLZ', '1CP8', '1CP8', '1CPO', '1CT1', '1CT1', '1CVI', '1CVI', '1CVI', '1CVN', '1CVN', '1CVN', '1CVN', '1CXP', '1CXP', '1D2V', '1D2V', '1D5L', '1D5L', '1D7W', '1D7W', '1D83', '1D83', '1DBG', '1DBO', '1DEO', '1DEX', '1DGL', '1DGL', '1DIY', '1DL2', '1DN2', '1DN2', '1DNU', '1DNU', '1DNW', '1DNW', '1DOG', '1DOG', '1DP5', '1DPJ', '1DWA', '1DWA', '1DWF', '1DWF', '1DWG', '1DWG', '1DWH', '1DWH', '1DWI', '1DWI', '1DWJ', '1DWJ', '1DZH', '1E04', '1E05', '1E4K', '1E4K', '1E4M', '1E4M', '1E6Q', '1E6Q', '1E6S', '1E6S', '1E6X', '1E6X', '1E70', '1E70', '1E71', '1E71', '1E72', '1E72', '1E73', '1E73', '1EKH', '1EKH', '1EKI', '1EKI', '1EOM', '1ETH', '1ETH', '1EX1', '1F6A', '1F6A', '1F8B', '1F8C', '1F8D', '1F8E', '1FC1', '1
W81', '7QN8', '3U0P', '5OHI', '6NF5', '4RFB', '3C5X', '6N4Y', '4UTA', '6EPK', '7PUR', '6MF0', '6EZN', '2DU1', '3H32', '3P5D', '1NCB', '5F93', '5VKI', '8AIC', '3GMR', '3R2X', '3V9C', '6AQ5', '3ZW1', '7T2P', '5YMT', '6A6M', '1Y2V', '7L87', '5M7M', '6L76', '6PZY', '2X96', '3D11', '5ZV5', '5NQW', '1C1Z', '7JHK', '4GKO', '4XMY', '1V55', '5VN3', '5J7Z', '5TZN', '3U2S', '5NFF', '5ZV7', '5DJZ', '7MN8', '5LSH', '1WHT', '3W3L', '6CE0', '1E6X', '3ZNM', '3HG4', '7MN5', '6YCG', '5NO7', '6E7S', '4EI5', '7Z14', '7BHD', '4MMZ', '4XN3', '5NZ4', '6FYW', '1JS8', '4PD6', '5LFR', '5MOL', '5OLB', '3FYI', '6H9Y', '7JHL', '8EW1', '7KDM', '5KIQ', '2TEP', '1HM2', '5AZ5', '1DIY', '6OJ1', '4DO6', '7BRJ', '5ANN', '2VDR', '1CLZ', '4KMB', '8FIS', '5A58', '4J4P', '5NN5', '6VY2', '2QWK', '1EX1', '2Y69', '3EYV', '4URR', '2Q7N', '5S9L', '6PW0', '6TCW', '8SAQ', '6WY0', '1C3M', '6D6U', '1SL6', '1HD4', '3WEO', '4J4Q', '7QUR', '5E62', '6VO3', '7S6N', '4UM8', '5FMD', '6IBM', '6P72', '7LF5', '6NWE', '5M8S', '1S4O', '3SGJ', '3WEN', '7QA4', '1LQ8', '1G1R', '7TMZ', '4CVU' ...
#  Number of unique pdbs: 3347
# ===================================================================
#
# ============= Downloading pdd file from RCSB pdb ===================
# Dir:  ../../pdbs/ - already exists
# 7LER failed to download
# 6IQH failed to download
# 5T3X failed to download
# 7Y6T failed to download
# failed to download count 4
# pdbs_filtered: ['6KA7', '4PXF', '6I2K', '5T20', '7UNY', '2GYS', '4Q56', '7LL1', '1JNE', '6HJP', '5F9D', '4AA1', '3ILF', '5JII', '6WJ1', '6CXF', '7KC1', '6CHF', '1CPO', '2XJR', '4R2G', '4WA2', '4WI9', '6HUS', '6UWZ', '2RDG', '6HFC', '6Z7D', '5U81', '8OK5', '8EJI', '4UNY', '2DTS', '3ZQZ', '2WBJ', '4KVK', '7CYC', '4GWM', '3OKW', '5WAV', '7QN5', '5XJW', '6IBK', '4GMS', '8G3R', '7MN6', '8SI9', '4WEG', '1E6S', '5D9Q', '5E4J', '6MUB', '5XJY', '8BXY', '4L37', '5K65', '7API', '2QC1', '2VUO', '6Z7A', '7ND4', '7PVD', '1FQ8', '4P2O', '7NI1', '1IGT', '5DK2', '7BRI', '8EMR', '7B75', '6H3W', '4P4F', '1DWH', '6CJC', '1MQM', '6URH', '6N9T', '4UO6', '4GTZ', '4H53', '6Z7B', '4ADF', '6GVR', '7LAN', '7KKB', '7JTV', '3AG3', '1OQX', '5LF5', '6AOR', '4AH4', '6Q05', '3OMI
2', '1SR0', '6XTG', '3GML', '7KBK', '2QWI', '4XPF', '2C8N', '8DD2', '7A0T', '4MWJ', '6PZE', '2ZL6', '2GD4', '3USU', '3PQR', '3ZE0', '6HUJ', '1E4K', '4MCP', '5F7M', '3H54', '5E34', '3WJJ', '1MFE', '8C1C', '3S5Z', '7ORB', '5S9N', '5HYF', '7MLZ', '8F0S', '3W81', '7QN8', '3U0P', '5OHI', '6NF5', '4RFB', '3C5X', '6N4Y', '4UTA', '6EPK', '7PUR', '6MF0', '6EZN', '2DU1', '3H32', '3P5D', '1NCB', '5F93', '5VKI', '8AIC', '3GMR', '3R2X', '3V9C', '6AQ5', '3ZW1', '7T2P', '5YMT', '6A6M', '1Y2V', '7L87', '5M7M', '6L76', '6PZY', '2X96', '3D11', '5ZV5', '5NQW', '1C1Z', '7JHK', '4GKO', '4XMY', '1V55', '5VN3', '5J7Z', '5TZN', '3U2S', '5NFF', '5ZV7', '5DJZ', '7MN8', '5LSH', '1WHT', '3W3L', '6CE0', '1E6X', '3ZNM', '3HG4', '7MN5', '6YCG', '5NO7', '6E7S', '4EI5', '7Z14', '7BHD', '4MMZ', '4XN3', '5NZ4', '6FYW', '1JS8', '4PD6', '5LFR', '5MOL', '5OLB', '3FYI', '6H9Y', '7JHL', '8EW1', '7KDM', '5KIQ', '2TEP', '1HM2', '5AZ5', '1DIY', '6OJ1', '4DO6', '7BRJ', '5ANN', '2VDR', '1CLZ', '4KMB', '8FIS', '5A58', '4J4P', '5NN5', '6VY2', '2QWK', '1EX1', '2Y69', '3EYV', '4URR', '2Q7N', '5S9L', '6PW0', '6TCW', '8SAQ', '6WY0', '1C3M', '6D6U', '1SL6', '1HD4', '3WEO', '4J4Q', '7QUR', '5E62', '6VO3', '7S6N', '4UM8', '5FMD', '6IBM', '6P72', '7LF5', '6NWE', '5M8S', '1S4O', '3SGJ', '3WEN', '7QA4', '1LQ8', '1G1R',  ...
# ===================================================================
# {'146D': {'glycan_name': ['DAltp[6H,2H,3<R1>]b1-3DTalp[6H,2H]b1-3DOlipb1-', 'DAltp[6H,2H,3<R1>]b1-3DTalp[6H,2H]b1-3DOlipb1-'], 'glycan_residueID': ['MDA(3_D_)-DDL(2_D_)-DDA(1_D_)', 'MDA(3_F_)-DDL(2_F_)-DDA(1_F_)']}, '1A14': {'glycan_name': ['DManpa1-2DManpa1-2DManpa1-3DManpb1-4DGlcpNAcb1-4DGlcpNAcb1-ASN'], 'glycan_residueID': ['MAN(6_A_)-MAN(5_A_)-MAN(4_A_)-BMA(3_A_)-NAG(2_A_)-NAG(1_A_)-ASN(200_N_)']}, '1ABR': {'glycan_name': ['DManpb1-3[DManpa1-6]DGlcpa1-4LGlcpNAca1-4DGlcpNAcx1-', 'DManpb1-3[DManpa1-6]DGlcpb1-4LManpNAca1-4DGlcpNAcx1-'], 'glycan_residueID': ['MAN(5_C_)-[BMA(4_C_)]-MAN(3_C_)-NGZ(2_C_)-NDG(1_C_)', 'MAN(5_D_)-[BMA(4_D_)]-BGC(3_D_)-NDG(2_D_)-NDG(1_D_)']}, '1AGM': {'glycan_name': ['DManpa1-2DManpa1-3DManpb1-4DGlcpNAcb1-4DGlcpNAcb1-ASN', 'DManpa1-2DManpa1-2DManpa1-3[DManpa1-3DManpa1-6]DManpb1-4DGlcpNAcb1-4DGlcpNAcb1-ASN'], 'glycan_residueID': ['MAN(5_B_)-MAN(4_B_)-BMA(3_B_)-NAG(2_B_)-NAG(1_B_)-ASN(171_A_)', 'MAN(8_C_)-MAN(7_C_)-[MAN(6_C_)-MAN(5_C_)-MAN(4_C_)]-BMA(3_C_)-NAG(2_C_)-NAG(1_C_)-ASN(395_A_)']}, '1AX0': {'glycan_name': ['DXylpb1-2[DManpa1-3][DManpa1-6]DManpb1-4DGlcpNAcb1-4[LFucpa1-3]DGlcpNAcb1-ASN'], 'glycan_residueID': ['MAN(6_B_)-[MAN(5_B_)]-[XYP(4_B_)]-BMA(3_B_)-NAG(2_B_)-[FUC(7_B_)]-NAG(1_B_)-ASN(17_A_)']}, '1AX1': {'glycan_name': ['DXylpb1-2[DManpa1-3][DManpa1-6]DManpb1-4DGlcpNAcb1-4[LFucpa1-3]DGlcpNAcb1-ASN'], 'glycan_residueID': ['MAN(6_B_)-[MAN(5_B_)]-[XYP(4_B_)]-BMA(3_B_)-NAG(2_B_)-[FUC(7_B_)]-NAG(1_B_)-ASN(17_A_)']}, '1AX2': {'glycan_name': ['DXylpb1-2[DManpa1-3][DManpa1-6]DManpb1-4DGlcpNAcb1-4[LFucpa1-3]DGlcpNAcb1-ASN'], 'glycan_residueID': ['MAN(6_B_)-[MAN(5_B_)]-[XYP(4_B_)]-BMA(3_B_)-NAG(2_B_)-[FUC(7_B_)]-NAG(1_B_)-ASN(17_A_)']}, '1AXY': {'glycan_name': ['DXylpb1-2[DManpa1-3][DManpa1-6]DManpb1-4DGlcpNAcb1-4[LFucpa1-3]DGlcpNAcb1-ASN'], 'glycan_residueID': ['MAN(6_B_)-[MAN(5_B_)]-[XYP(4_B_)]-BMA(3_B_)-NAG(2_B_)-[FUC(7_B_)]-NAG(1_B_)-ASN(17_A_)']}, '1AXZ': {'glycan_name': ['DXylpb1-2[DManpa1-3][DManpa1-6]DManpb1-4DGlcpNAcb1-4[LFucpa1-3]DGlcpNAcb1-ASN'], 'glycan_residueID': ['MAN(6_B_)-[MAN(5_B_)]-[XYP(4_B_)]-BMA(3_B_)-NAG(2_B_)-[FUC(7_B_)]-NAG(1_B_)-ASN(17_A_)']}, '1AY2': {'glycan_name': ['DGalpa1-3DGlcpNAcb1-SER'], 'glycan_residueID': ['GLA(2_B_)-NAG(1_B_)-SER(63_A_)']}, '1B37': {'glycan_name': ['DFucpa1-3DGlcpNAcb1-ASN'], 'glycan_residueID': ['FCA(5_F_)-NAG(1_F_)-ASN(77_C_)']}, '1B5F': {'glycan_name': ['DManpa1-3[DManpa1-6]DManpb1-4DGlcpNAcb1-4[LFucpa1-3]DGlcpNAcb1-ASN', 'DManpa1-4DGlcpNAcb1-4[LFucpa1-3]DGlcpNAcb1-ASN', 'DManpb1-4DGlcpNAcb1-4[LFucpa1-3]DGlcpNAcb1-ASN', 'DManpa1-3DManpb1-4DGlcpNAcb1-4[LFucpa1-3]DGlcpNAcb1-ASN'], 'glycan_residueID': ['MAN(5_G_)-[MAN(4_G_)]-BMA(3_G_)-NAG(2_G_)-[FUC(6_G_)]-NAG(1_G_)-ASN(67_C_)', 'BMA(3_H_)-NAG(2_H_)-[FUC(4_H_)]-NAG(1_H_)-ASN(257_D_)', 'BMA(3_F_)-NAG(2_F_)-[FUC(4_F_)]-NAG(1_F_)-ASN(257_B_)', 'MAN(4_E_)-BMA(3_E_)-NAG(2_E_)-[FUC(5_E_)]-NAG(1_E_)-ASN(67_A_)']}, '1B5Q': {'glycan_name': ['DFucpa1-3DGlcpNAcb1-ASN'], 'glycan_residueID': ['FCA(5_F_)-NAG(1_F_)-ASN(77_C_)']}, '1BCS': {'glycan_name': ['LFucpa1-3[DManpNAca1-4]DGlcpNAcx1-'], 'glycan_residueID': ['NDG(3_D_)-[FUC(2_D_)]-NAG(1_D_)']}, '1BHG': {'glycan_name': ['DManpa1-2DManpa1-6[DManpa1-3]DManpa1-6[DManpa1-2DManpa1-3]DManpb1-4DGlcpNAcb1-4DGlcpNAcb1-ASN', 'DManpa1-2DManpa1-6[DManpa1-3]DManpa1-6[DManpa1-2DManpa1-3]DManpb1-4DGlcpNAcb1-4DGlcpNAcb1-ASN'], 'glycan_residueID': ['MAN(6_D_)-MAN(5_D_)-[MAN(7_D_)]-MAN(4_D_)-[MAN(9_D_)-MAN(8_D_)]-BMA(3_D_)-NAG(2_D_)-NAG(1_D_)-ASN(173_B_)', 'MAN(6_C_)-MAN(5_C_)-[MAN(7_C_)]-MAN(4_C_)-[MAN(9_C_)-MAN(8_C_)]-BMA(3_C_)-NAG(2_C_)-NAG(1_C_)-ASN(173_A_)']}, '1BJI': {'glycan_name': ['DManpa1-2DManpa1-2DManpa1-3DManpb1-4DGlcpNAcb1-4DGlcpNAcb1-ASN'], 'glycan_residueID': ['MAN(6_B_)-MAN(5_B_)-MAN(4_B_)-BMA(3_B_)-NAG(2_B_)-NAG(1_B_)-ASN(200_A_)']}, '1BLF': {'glycan_name': ['DManpa1-3[DManpa1-6]DManpa1-6DManpb1-4DGlcpNAcb1-4DGlcpNAcb1-ASN'], 'glycan_residueID': ['MAN(6_C_)-[MAN(5_C_)]-MAN(4_C_)-BMA(3_C_)-NAG(2_C_)-NAG(1_C_)-ASN(545_A_)']}, '1BP8': {'glycan_name': ['DAltp[6H,2 ...
# total_pdb_count: 3347
# glycosite_count: 8612

# %%
# %%capture output
instant1.generate_chimerax_script_to_compute_dihedral()

# %%
# Write the entire output to a file
with open('calc_dihedral2.cxc', 'w') as f:
    f.write(output.stdout)

# %%
# Use the custom split function
instant1.custom_split_chimerax_script('calc_dihedral2.cxc', 'calc_dihedral_part_')
# Out:
# chimerax script is run parallely in ./calc_dihedral_chimerax
# Split into 1 files.

# %%
# Run the parallel execution and stitching
instant1.run_chimerax_script_parallel('./calc_dihedral_chimerax/calc_dihedral_part_*.cxc')
# Out:
# Executed 1 ChimeraX scripts in parallel.
# Combined outputs into:  combined_chimerax_output.out

# %%
# instant1.run_chimerax_script('calc_dihedral2.cxc', 'calc_dihedral2.out')

# %%
# torsions = instant1.clean_up_chimerax_output('calc_dihedral2.out')
torsions = instant1.clean_up_chimerax_output('combined_chimerax_output.out')
torsions.to_csv('chimerax_output.csv', index=False)
# Out:
# number of pdb read: 2
# valid torsion1 and torsion2: (2, 2)

# %%
instant1.calc_BFactor()

# %%
instant1.find_bfmp_ring_shape()
# Out:
# (['8.A', '7.A'], ['4C1', '4C1'])
# (['4.A', '3.A'], ['4C1', '4C1'])

# %%
output_df = instant1.match_glycan_tree()
# Out:
# ../../pdbs//1cap.pdb A MAN 8 C1
# ../../pdbs//1cap.pdb A BGC 7 O3
# 125 114
# Connection found between 125 and 114
# ../../pdbs//1cap.pdb A MAN 4 C1
# ../../pdbs//1cap.pdb A BGC 3 O3
# 54 43
# Connection found between 54 and 43
# droped rows: []

# %%
output_df.to_csv('DManpa1-3DGlcpb_ver2.1.csv',sep=',',index=False, columns=['pdb','glycam name','glycan','phi site','psi site','phi','psi','B factor(Avg)','BFMP ring shape'])
output_df.to_csv('DManpa1-3DGlcpb_ver3.csv',sep=',',index=False, columns=['pdb','phi site','psi site','phi','psi','B factor(Avg)','BFMP ring shape'])

# %%
################################
# print(instant1.pdbs)
# print(instant1.pdb_glycan_dict)

# %%
instant1.torsions
# Out:
#         pdb                   phi site                   psi site      phi  \
# 0  1cap.pdb  A MAN 8 C2 C1 BGC 7 O3 C3  A MAN 8 C1 BGC 7 O3 C3 C4  196.413
# 1  1cap.pdb  A MAN 4 C2 C1 BGC 3 O3 C3  A MAN 4 C1 BGC 3 O3 C3 C4  196.413
#
#        psi                         B factor(Avg)  \
# 0  106.421  ([MAN(8_A_), BGC(7_A_)], [0.0, 0.0])
# 1  106.421  ([MAN(4_A_), BGC(3_A_)], [0.0, 0.0])
#
#                                               glycan  \
# 0  MAN(11_A_)-MAN(9_A_)-[MAN(8_A_)-BGC(7_A_)]-BDP...
# 1  MAN(11_A_)-MAN(9_A_)-[MAN(8_A_)-BGC(7_A_)]-BDP...
#
#                                          glycam name           BFMP ring shape
# 0  DManpa1-3DGlcpb1-3[DManp[2<R1>]a1-4]DGlcpAb1-3...  ([8.A, 7.A], [4C1, 4C1])
# 1  DManpa1-3DGlcpb1-3[DManp[2<R1>]a1-4]DGlcpAb1-3...  ([4.A, 3.A], [4C1, 4C1])

# %%
instant1.plot(torsions=instant1.torsions, title='DManpa1-3DGlcpb',max_histogram_scale=100,step_histogram_tick=20)
