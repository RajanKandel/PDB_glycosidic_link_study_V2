# %%
import sys
import subprocess
import os 

import glob
import multiprocessing

# %%
sys.path.append('../../')
from extract_glycan_info import parse_gf_result
# Out:
# ===============================================================================
# Script: Find glycosidic dihedral, average B-factor, and ring shape of glycans from PDB
# Author:Rajan Kandel <rajan.kandel@uga.edu>
#       *Woods Group, CCRC UGA
#
# Currently under development.......
# Last Update: Oct 2024
#
# Citations:
# 1. https://glycam.org/cb/
# 2. https://glycam.org/portal/gf_home/
#
# ===============================================================================

# %%
phi_dihedral=['C2','C1','O6','C6']
psi_dihedral=['C1','O6','C6','C5']

di_sugar=['GLC', 'NDG']
di_sugar2= ['DGlcpa', 'DGlcpNAca']
link= '1-6'
patterns1= [di_sugar[0]+'(*_*_)]-'+di_sugar[1]+'(*_*_)', di_sugar[0]+'(*_*_)-'+di_sugar[1]+'(*_*_)',di_sugar[0]+'(*_*_)]-[*]-'+di_sugar[1]+'(*_*_)', di_sugar[0]+'(*_*_)-[*]-'+di_sugar[1]+'(*_*_)']
patterns2= [di_sugar2[0]+link+di_sugar2[1], di_sugar2[0]+link+']'+di_sugar2[1], di_sugar2[0]+link+'[*]'+di_sugar2[1]]
patterns=(patterns1,patterns2)

gf_result ='../../data_gf_query/a1-6D_GF_results.csv'

chimerax_path= '/bin/chimerax'
bfmp_path = '/home/rajan/apps/BFMP/detect_shape'


instant1 = parse_gf_result(gf_result, phi_dihedral, psi_dihedral, di_sugar, patterns, chimerax_path, bfmp_path)
instant1.read_gf_file()
instant1.dnl_pdbs()
instant1.create_pdb_glycan_dict() 
instant1.glycan_count()
instant1.select_pdbs()
# Out:
# ========== Reading_gf_results =====================================
# pdbs: ['1A7C', '1ABR', '1ABR', '1AGM', '1AH1', '1AU1', '1AU1', '1AX0', '1AX1', '1AX2', '1AXY', '1AXZ', '1B0F', '1B0F', '1B37', '1B41', '1B5F', '1B5Q', '1BHG', '1BHG', '1BLF', '1BRR', '1BRR', '1BZB', '1C1Z', '1CDR', '1CF5', '1CF5', '1CKL', '1CKL', '1CKL', '1CKL', '1CPO', '1CVI', '1CVI', '1CVI', '1CVI', '1CVN', '1CVN', '1CVN', '1CVN', '1CVU', '1CVU', '1CXP', '1CXP', '1D2V', '1D2V', '1D5L', '1D5L', '1D7W', '1D7W', '1DEO', '1DEX', '1DGL', '1DGL', '1DIY', '1DL2', '1DN2', '1DN2', '1DNU', '1DNU', '1DNW', '1DNW', '1DOG', '1DP5', '1DPJ', '1DWA', '1DWF', '1DWG', '1DWH', '1DWI', '1DWJ', '1DZE', '1E04', '1E05', '1E4K', '1E4K', '1E6Q', '1E6S', '1EOM', '1ETH', '1ETH', '1EX1', '1F6A', '1F6A', '1F6A', '1F6A', '1F8B', '1F8C', '1F8D', '1F8E', '1F8R', '1F8R', '1F8R', '1FC1', '1FC1', '1FC2', '1FE2', '1FE8', '1FE8', '1FE8', '1FI1', '1FRT', '1FRT', '1FUJ', '1FUJ', '1FUJ', '1FUJ', '1FX5', '1FZD', '1FZD', '1FZD', '1FZD', '1G0V', '1G6I', '1G6I', '1G7P', '1G7Q', '1G82', '1G82', '1G82', '1G9M', '1G9M', '1G
9L', '6JLM', '6QAD', '4TNK', '5W5N', '3LRL', '6TRF', '2WNE', '8BEU', '7SO9', '7QZR', '8DL1', '6FIF', '1NHC', '5B66', '7BLX', '4CQU', '2QC1', '4BZS', '5W26', '1X0S', '6MF0', '7TNW', '5V5X', '4PSP', '8D4U', '8G3O', '7Y5X', '3NXQ', '6H5W', '4BFO', '6MTN', '4GTY', '4MZE', '8EQM', '6VEQ', '5U4Y', '7SBP', '6U7K', '7KEX', '4QN4', '1CXP', '2DSZ', '3IB0', '1EOM', '2PHR', '4J3W', '1FUJ', '7L8C', '7LO4', '5L88', '6MUG', '3B9F', '4LN6', '7MZH', '3O8X', '2XJR', '7Y6T', '6ZGF', '2D0H', '7DMU', '4OIB', '4Y19', '4TNJ', '1DEX', '7KEI', '6B3M', '6VC9', '6E7U', '5OYD', '7LBE', '2YOR', '4HF5', '7D0J', '4FOM', '7ALK', '6NHQ', '6YP7', '6D58', '4MR8', '7A3O', '6XC9', '7UHB', '1B0F', '7UAE', '6C26', '3PXL', '5FK8', '6IJJ', '6L35', '5NSG', '7Y5Z', '3MJ7', '1E05', '6VI0', '6S82', '6OJB', '3CSY', '2RI8', '6ORQ', '7LX2', '1PPF', '7FBK' ...
#  Number of unique pdbs: 3296
# ===================================================================
#
# ============= Downloading pdd file from RCSB pdb ===================
# Dir:  ../../pdbs/ - already exists
# 7Y6T failed to download
# 7LER failed to download
# 6IQH failed to download
# 5T3X failed to download
# failed to download count 4
# pdbs_filtered: ['4CXV', '5EOK', '6CH9', '7D1U', '6MJJ', '7B75', '6X3U', '5FI9', '6E3K', '4MMX', '6E3L', '5VC1', '2ZX3', '8PE9', '4BM7', '7SI0', '2QWG', '5U7M', '5THB', '7YMW', '6ARQ', '7SLV', '5U66', '6HP0', '7NEG', '7N28', '3UUE', '4OVE', '3TYG', '1QDC', '4UM9', '4UO4', '6V0R', '6IBM', '4C1M', '6KRN', '5K6W', '2B8H', '6EPY', '7NWL', '1IW9', '6E4X', '6GVP', '6OHE', '6BDZ', '5NIT', '1K9J', '6Y5W', '3HG4', '8GN1', '8DPL', '3K41', '5SZO', '7JPI', '7YMY', '5VL3', '4C2Q', '6DFH', '6FHW', '6V06', '5BK3', '6YT7', '8BH5', '8F4G', '3LPO', '3W7X', '1IGY', '4UNY', '5WIW', '6EPZ', '6CW9', '7Y7B', '8CYB', '1H81', '6CJX', '4N0U', '3BVX', '5D9Q', '3IJE', '2X85', '4EY8', '6A5D', '1CVI', '6EAY', '6VFV', '4WK4', '5N2J', '7D9O', '7JHK', '7Y45', '5T3Z', '4O6D', '6ZWI', '1LEK', '1KJ2', '2GD4', '7B38', '5EHQ', '6BGA', '2QQV', '8T2U', '7SKA', '1AXZ', '4GZT', '1GW0', '2QQW', '7PC2', '6VSL', '4WI7', '6WPT', '6Q1P', '6VKN', '6KRL', '7QUS', '5VKJ', '5AWA', '8IUC', '3HG2', '6CQX', '2DWJ', '3GMQ', '2FCP', '7XWA', '1TYE', '3WO4', '6ORN', '4XHQ', '7MF1', '7P2P', '5D9M', '1OZN', '3HN3', '5HDH', '7Q0G', '4K
7Q3Y', '1ZHN', '2B9L', '6JLM', '6QAD', '4TNK', '5W5N', '3LRL', '6TRF', '2WNE', '8BEU', '7SO9', '7QZR', '8DL1', '6FIF', '1NHC', '5B66', '7BLX', '4CQU', '2QC1', '4BZS', '5W26', '1X0S', '6MF0', '7TNW', '5V5X', '4PSP', '8D4U', '8G3O', '7Y5X', '3NXQ', '6H5W', '4BFO', '6MTN', '4GTY', '4MZE', '8EQM', '6VEQ', '5U4Y', '7SBP', '6U7K', '7KEX', '4QN4', '1CXP', '2DSZ', '3IB0', '1EOM', '2PHR', '4J3W', '1FUJ', '7L8C', '7LO4', '5L88', '6MUG', '3B9F', '4LN6', '7MZH', '3O8X', '2XJR', '6ZGF', '2D0H', '7DMU', '4OIB', '4Y19', '4TNJ', '1DEX', '7KEI', '6B3M', '6VC9', '6E7U', '5OYD', '7LBE', '2YOR', '4HF5', '7D0J', '4FOM', '7ALK', '6NHQ', '6YP7', '6D58', '4MR8', '7A3O', '6XC9', '7UHB', '1B0F', '7UAE', '6C26', '3PXL', '5FK8', '6IJJ', '6L35', '5NSG', '7Y5Z', '3MJ7', '1E05', '6VI0', '6S82', '6OJB', '3CSY', '2RI8', '6ORQ', '7LX2', '1PPF',  ...
# ===================================================================
# {'1A7C': {'glycan_name': ['DGlcpNAcb1-4[DArapb1-6]DGlcpNAcb1-ASN'], 'glycan_residueID': ['RIP(3_D_)-[NAG(2_D_)]-NAG(1_D_)-ASN(265_A_)']}, '1ABR': {'glycan_name': ['DManpb1-3[DManpa1-6]DGlcpa1-4LGlcpNAca1-4DGlcpNAcx1-', 'DManpb1-3[DManpa1-6]DGlcpb1-4LManpNAca1-4DGlcpNAcx1-'], 'glycan_residueID': ['MAN(5_C_)-[BMA(4_C_)]-MAN(3_C_)-NGZ(2_C_)-NDG(1_C_)', 'MAN(5_D_)-[BMA(4_D_)]-BGC(3_D_)-NDG(2_D_)-NDG(1_D_)']}, '1AGM': {'glycan_name': ['DManpa1-2DManpa1-2DManpa1-3[DManpa1-3DManpa1-6]DManpb1-4DGlcpNAcb1-4DGlcpNAcb1-ASN'], 'glycan_residueID': ['MAN(8_C_)-MAN(7_C_)-[MAN(6_C_)-MAN(5_C_)-MAN(4_C_)]-BMA(3_C_)-NAG(2_C_)-NAG(1_C_)-ASN(395_A_)']}, '1AH1': {'glycan_name': ['DManpb1-4DGlcpNAcb1-4[LFucpa1-6]DGlcpNAcb1-ASN'], 'glycan_residueID': ['FUC(4_C_)-[BMA(3_C_)-NAG(2_C_)]-NAG(1_C_)-ASN(78_A_)']}, '1AU1': {'glycan_name': ['DGlcpb1-4DGlcpb1-2DGlcpb1-3DGlcpb1-4DGlcpb1-4[DQuipa1-6]DGlcpb1-ASN', 'DQuipa1-6DGlcpb1-ASN'], 'glycan_residueID': ['G6D(7_C_)-[BGC(6_C_)-BGC(5_C_)-BGC(4_C_)-BGC(3_C_)-BGC(2_C_)]-BGC(1_C_)-ASN(80_A_)', 'G6D(2_D_)-BGC(1_D_)-ASN(80_B_)']}, '1AX0': {'glycan_name': ['DXylpb1-2[DManpa1-3][DManpa1-6]DManpb1-4DGlcpNAcb1-4[LFucpa1-3]DGlcpNAcb1-ASN'], 'glycan_residueID': ['MAN(6_B_)-[MAN(5_B_)]-[XYP(4_B_)]-BMA(3_B_)-NAG(2_B_)-[FUC(7_B_)]-NAG(1_B_)-ASN(17_A_)']}, '1AX1': {'glycan_name': ['DXylpb1-2[DManpa1-3][DManpa1-6]DManpb1-4DGlcpNAcb1-4[LFucpa1-3]DGlcpNAcb1-ASN'], 'glycan_residueID': ['MAN(6_B_)-[MAN(5_B_)]-[XYP(4_B_)]-BMA(3_B_)-NAG(2_B_)-[FUC(7_B_)]-NAG(1_B_)-ASN(17_A_)']}, '1AX2': {'glycan_name': ['DXylpb1-2[DManpa1-3][DManpa1-6]DManpb1-4DGlcpNAcb1-4[LFucpa1-3]DGlcpNAcb1-ASN'], 'glycan_residueID': ['MAN(6_B_)-[MAN(5_B_)]-[XYP(4_B_)]-BMA(3_B_)-NAG(2_B_)-[FUC(7_B_)]-NAG(1_B_)-ASN(17_A_)']}, '1AXY': {'glycan_name': ['DXylpb1-2[DManpa1-3][DManpa1-6]DManpb1-4DGlcpNAcb1-4[LFucpa1-3]DGlcpNAcb1-ASN'], 'glycan_residueID': ['MAN(6_B_)-[MAN(5_B_)]-[XYP(4_B_)]-BMA(3_B_)-NAG(2_B_)-[FUC(7_B_)]-NAG(1_B_)-ASN(17_A_)']}, '1AXZ': {'glycan_name': ['DXylpb1-2[DManpa1-3][DManpa1-6]DManpb1-4DGlcpNAcb1-4[LFucpa1-3]DGlcpNAcb1-ASN'], 'glycan_residueID': ['MAN(6_B_)-[MAN(5_B_)]-[XYP(4_B_)]-BMA(3_B_)-NAG(2_B_)-[FUC(7_B_)]-NAG(1_B_)-ASN(17_A_)']}, '1B0F': {'glycan_name': ['DGlcpNAcb1-4[LFucpa1-6]DGlcpNAcb1-ASN', 'DGlcpNAcb1-4[LFucpa1-6]DGlcpNAcb1-ASN'], 'glycan_residueID': ['FUC(3_B_)-[NAG(2_B_)]-NAG(1_B_)-ASN(109_A_)', 'FUC(3_C_)-[NAG(2_C_)]-NAG(1_C_)-ASN(159_A_)']}, '1B37': {'glycan_name': ['DManpa1-6DManpa1-4DGlcpNAcx1-'], 'glycan_residueID': ['MAN(4_F_)-MAN(3_F_)-NAG(2_F_)']}, '1B41': {'glycan_name': ['DGlcpNAcb1-4[LFucpa1-6]DGlcpNAcb1-ASN'], 'glycan_residueID': ['FUC(3_C_)-[NAG(2_C_)]-NAG(1_C_)-ASN(350_A_)']}, '1B5F': {'glycan_name': ['DManpa1-3[DManpa1-6]DManpb1-4DGlcpNAcb1-4[LFucpa1-3]DGlcpNAcb1-ASN'], 'glycan_residueID': ['MAN(5_G_)-[MAN(4_G_)]-BMA(3_G_)-NAG(2_G_)-[FUC(6_G_)]-NAG(1_G_)-ASN(67_C_)']}, '1B5Q': {'glycan_name': ['DManpa1-6DManpx1-'], 'glycan_residueID': ['MAN(4_F_)-MAN(3_F_)']}, '1BHG': {'glycan_name': ['DManpa1-2DManpa1-6[DManpa1-3]DManpa1-6[DManpa1-2DManpa1-3]DManpb1-4DGlcpNAcb1-4DGlcpNAcb1-ASN', 'DManpa1-2DManpa1-6[DManpa1-3]DManpa1-6[DManpa1-2DManpa1-3]DManpb1-4DGlcpNAcb1-4DGlcpNAcb1-ASN'], 'glycan_residueID': ['MAN(6_D_)-MAN(5_D_)-[MAN(7_D_)]-MAN(4_D_)-[MAN(9_D_)-MAN(8_D_)]-BMA(3_D_)-NAG(2_D_)-NAG(1_D_)-ASN(173_B_)', 'MAN(6_C_)-MAN(5_C_)-[MAN(7_C_)]-MAN(4_C_)-[MAN(9_C_)-MAN(8_C_)]-BMA(3_C_)-NAG(2_C_)-NAG(1_C_)-ASN(173_A_)']}, '1BLF': {'glycan_name': ['DManpa1-3[DManpa1-6]DManpa1-6DManpb1-4DGlcpNAcb1-4DGlcpNAcb1-ASN'], 'glycan_residueID': ['MAN(6_C_)-[MAN(5_C_)]-MAN(4_C_)-BMA(3_C_)-NAG(2_C_)-NAG(1_C_)-ASN(545_A_)']}, '1BRR': {'glycan_name': ['DGalp[3S]b1-6DManpa1-2DGlcpa1-C43O3', 'DGalp[3S]b1-6DManpa1-2DGlcpa1-C43O3'], 'glycan_residueID': ['SGA(3_E_)-MAN(2_E_)-GLC(1_E_)', 'SGA(3_D_)-MAN(2_D_)-GLC(1_D_)']}, '1BZB': {'glycan_name': ['DManpa1-2DManpa1-3[DManpa1-3[DManpa1-6]DManpa1-6]DManpb1-4DGlcpNAcb1-4DGlcpNAcb1-ASN'], 'glycan_residueID': ['MAN(8_B_)-[MAN(7_B_)]-MAN(6_B_)-[MAN(5_B_)-MAN(4_B_)]-MAN(3_B_)-NAG(2_B_)-NAG(1_B_)-ASN(3 ...
# total_pdb_count: 3296
# glycosite_count: 8664

# %%
# %%capture output
instant1.generate_chimerax_script_to_compute_dihedral()

# %%
# Write the entire output to a file
with open('calc_dihedral2.cxc', 'w') as f:
    f.write(output.stdout)

# %%
# Use the custom split function
instant1.custom_split_chimerax_script('calc_dihedral2.cxc', 'calc_dihedral_part_')
# Out:
# chimerax script is run parallely in ./calc_dihedral_chimerax
# Split into 1 files.

# %%
# Run the parallel execution and stitching
instant1.run_chimerax_script_parallel('./calc_dihedral_chimerax/calc_dihedral_part_*.cxc')
# Out:
# Executed 1 ChimeraX scripts in parallel.
# Combined outputs into:  combined_chimerax_output.out

# %%
# instant1.run_chimerax_script('calc_dihedral2.cxc', 'calc_dihedral2.out')

# %%
# torsions = instant1.clean_up_chimerax_output('calc_dihedral2.out')
torsions = instant1.clean_up_chimerax_output('combined_chimerax_output.out')
torsions.to_csv('chimerax_output.csv', index=False)
# Out:
# number of pdb read: 4
# valid torsion1 and torsion2: (4, 4)

# %%
instant1.calc_BFactor()

# %%
instant1.find_bfmp_ring_shape()
# Out:
# (['6.B', '1.B'], ['4C1', '4C1'])
# (['3.B', '1.B'], ['4C1', '4C1'])
# (['6.B', '1.B'], ['4C1', '4C1'])
# (['3.B', '1.B'], ['4C1', '4C1'])

# %%
output_df = instant1.match_glycan_tree()
# Out:
# ../../pdbs//6gvp.pdb B GLC 6 C1
# ../../pdbs//6gvp.pdb B NDG 1 O6
# 4699 4649
# Connection found between 4699 and 4649
# ../../pdbs//6gvp.pdb B GLC 3 C1
# ../../pdbs//6gvp.pdb B NDG 1 O6
# 4664 4649
# No connection found between 4664 and 4649
# 1
# ../../pdbs//4xle.pdb B GLC 6 C1
# ../../pdbs//4xle.pdb B NDG 1 O6
# 4779 4729
# Connection found between 4779 and 4729
# ../../pdbs//4xle.pdb B GLC 3 C1
# ../../pdbs//4xle.pdb B NDG 1 O6
# 4744 4729
# No connection found between 4744 and 4729
# 3
# droped rows: [1, 3]

# %%
outfile_name = di_sugar2[0]+link+di_sugar2[1]

# %%
output_df.to_csv(outfile_name+'_ver2.1.csv',sep=',',index=False, columns=['pdb','glycam name','glycan','phi site','psi site','phi','psi','B factor(Avg)','BFMP ring shape'])
output_df.to_csv(outfile_name+'_ver3.csv',sep=',',index=False, columns=['pdb','phi site','psi site','phi','psi','B factor(Avg)','BFMP ring shape'])

# %%
################################
# print(instant1.pdbs)
# print(instant1.pdb_glycan_dict)

# %%
instant1.torsions
# Out:
#         pdb                   phi site                   psi site      phi  \
# 0  6gvp.pdb  B GLC 6 C2 C1 NDG 1 O6 C6  B GLC 6 C1 NDG 1 O6 C6 C5  194.084
# 1  6gvp.pdb  B GLC 3 C2 C1 NDG 1 O6 C6  B GLC 3 C1 NDG 1 O6 C6 C5  148.208
# 2  4xle.pdb  B GLC 6 C2 C1 NDG 1 O6 C6  B GLC 6 C1 NDG 1 O6 C6 C5  188.681
# 3  4xle.pdb  B GLC 3 C2 C1 NDG 1 O6 C6  B GLC 3 C1 NDG 1 O6 C6 C5  138.799
#
#        psi                             B factor(Avg)  \
# 0  86.1567  ([GLC(6_B_), NDG(1_B_)], [21.37, 16.25])
# 1  34.2375   ([GLC(3_B_), NDG(1_B_)], [19.5, 16.25])
# 2  87.8635  ([GLC(6_B_), NDG(1_B_)], [10.92, 11.48])
# 3  30.0137  ([GLC(3_B_), NDG(1_B_)], [17.53, 11.48])
#
#                                               glycan  \
# 0  GLC(6_B_)-[RAM(4_B_)-GLC(3_B_)-[NAG(5_B_)]-GLA...
# 1  GLC(6_B_)-[RAM(4_B_)-GLC(3_B_)-[NAG(5_B_)]-GLA...
# 2  GLC(6_B_)-[RAM(4_B_)-GLC(3_B_)-[NAG(5_B_)]-GLA...
# 3  GLC(6_B_)-[RAM(4_B_)-GLC(3_B_)-[NAG(5_B_)]-GLA...
#
#                                          glycam name           BFMP ring shape
# 0  LRhapa1-6DGlcpa1-4[DGlcpNAcb1-3]DGalpa1-3[DGlc...  ([6.B, 1.B], [4C1, 4C1])
# 1  LRhapa1-6DGlcpa1-4[DGlcpNAcb1-3]DGalpa1-3[DGlc...  ([3.B, 1.B], [4C1, 4C1])
# 2  LRhapa1-6DGlcpa1-4[DGlcpNAcb1-3]DGalpa1-3[DGlc...  ([6.B, 1.B], [4C1, 4C1])
# 3  LRhapa1-6DGlcpa1-4[DGlcpNAcb1-3]DGalpa1-3[DGlc...  ([3.B, 1.B], [4C1, 4C1])

# %%
instant1.plot(torsions=output_df, title=outfile_name,max_histogram_scale=100,step_histogram_tick=20)
